# %%
import numpy as np
import PIL
import tensorflow as tf
import matplotlib.pyplot as plt
from ipywidgets import interact
import seaborn as sns

# %%
test_feature = np.load("/media/2/Network/extracted_feature/whole_shuffle/testing_features.npy",mmap_mode="r")

# %%
test_feature.shape
# Out:
# (50000, 14, 14, 512)

# %%
test_feature[0][:,:,1].shape
# Out:
# (14, 14)

# %%
ch_1 = test_feature[0][:,:,1]
ch_1_img=PIL.Image.fromarray(ch_1)
ch_1_img.show()

# %%
w = 10
h = 10
cols = 32
rows = 16
@interact
def feature_print(pic_num=(27354)):
    print("test with 'after pooling 4 feature'")
    print("pic_num : "+str(pic_num))
    fig = plt.figure(figsize=(64,32))
    ax = []
    for i in range(cols*rows):
        ch = test_feature[pic_num][:,:,i]
        ax.append(fig.add_subplot(rows,cols,i+1))
        ax[-1].set_title(str(i)+"th ch (14x14)")
        plt.imshow(ch)
   
#plt.imshow(ch_1,cmap='gray')
# Out:
# test with 'after pooling 4 feature'
# pic_num : 27354

# %%
interact(feature_print,pic_num=511)
# Out:
# pic_num : 511
# <function __main__.feature_print(pic_num=range(0, 512))>

# %%
print(test_feature[0][:,:,64][1])
ch_1 = test_feature[5][:,:,63]
ch_1_img=PIL.Image.fromarray(ch_1)
fig, ax = plt.subplots(figsize=(15,15))
sns.heatmap(ch_1,annot=True,fmt='.1f',linewidths=7,ax=ax)
# Out:
# [90.777054 11.714157  0.       25.426617 34.8887    0.       25.037191
#   0.        0.        0.        0.        0.        0.        0.      ]

# %%
target=test_feature[0][:,:,64]

# %%
#same_ch = test_feature
test_feature[0].shape
# Out:
# (14, 14, 512)
